# %%
a=[1,2,3]

# %%
b='ala'

# %%
a.append(a)

# %%
a[-1][-1]
# Out:
# [1, 2, 3, 'ala', [...]]

# %% [markdown]
# Przykładowe zadanie:
# asdasdasd

# %% [markdown]
# asdasD

# %% [markdown]
# asd"

# %% [markdown]
# Przykładowy program do generowania wykresów.

# %%
from matplotlib import pyplot as plt
import numpy as np
X=np.linspace(-10,10,1000)
fig, ax = plt.subplots(1, figsize=((10,10)))
ax.plot(X, X**2)
plt.show()
